# %%
# import pandas, numpy and json_normalize
import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize

# %%
# To display full column width without hiding so we can see data better
pd.set_option('display.max_colwidth', -1)

# %%
# Load the JSON file as a string 
world_bank_str=json.load((open('data/world_bank_projects.json')))

# %%
# Use normalize to create table from the nested elements in mjtheme_namecode column
mjtheme_country_df=json_normalize(world_bank_str, 'mjtheme_namecode',['countryname','id'])

# %%
# Display the first 10 entries of the table
mjtheme_country_df.head(10)
# We can see the missing values under name which are entered as empty strings
# Out:
#   code                                          name  \
# 0  8    Human development
# 1  11
# 2  1    Economic management
# 3  6    Social protection and risk management
# 4  5    Trade and integration
# 5  2    Public sector governance
# 6  11   Environment and natural resources management
# 7  6    Social protection and risk management
# 8  7    Social dev/gender/inclusion
# 9  7    Social dev/gender/inclusion
#
#                                countryname       id
# 0  Federal Democratic Republic of Ethiopia  P129828
# 1  Federal Democratic Republic of Ethiopia  P129828
# 2  Republic of Tunisia                      P144674
# 3  Republic of Tunisia                      P144674
# 4  Tuvalu                                   P145310
# 5  Tuvalu                                   P145310
# 6  Tuvalu                                   P145310
# 7  Tuvalu                                   P145310
# 8  Republic of Yemen                        P144665
# 9  Republic of Yemen                        P144665

# %%
# Replace these missing strings with nan values for later use
mjtheme_country_df['name'].replace('',np.nan,inplace=True)

# %%
# Display that the missing strings have been replaced by NaN values
mjtheme_country_df.head(10)
# Out:
#   code                                          name  \
# 0  8    Human development
# 1  11   NaN
# 2  1    Economic management
# 3  6    Social protection and risk management
# 4  5    Trade and integration
# 5  2    Public sector governance
# 6  11   Environment and natural resources management
# 7  6    Social protection and risk management
# 8  7    Social dev/gender/inclusion
# 9  7    Social dev/gender/inclusion
#
#                                countryname       id
# 0  Federal Democratic Republic of Ethiopia  P129828
# 1  Federal Democratic Republic of Ethiopia  P129828
# 2  Republic of Tunisia                      P144674
# 3  Republic of Tunisia                      P144674
# 4  Tuvalu                                   P145310
# 5  Tuvalu                                   P145310
# 6  Tuvalu                                   P145310
# 7  Tuvalu                                   P145310
# 8  Republic of Yemen                        P144665
# 9  Republic of Yemen                        P144665

# %%
# Create a new dataframe which serves as a map between code and theme name
mjtheme_code_map=mjtheme_country_df[["code","name"]]

# %%
# Drop null values from rows
mjtheme_code_map_nonnull=mjtheme_code_map.dropna(axis=0,how="any")

# %%
# Drop all duplicates. Now we have a map between code and theme name which can be used to fill the missing values
mjtheme_code_map_nonnull.drop_duplicates()
# Out:
#     code                                          name
# 0    8    Human development
# 2    1    Economic management
# 3    6    Social protection and risk management
# 4    5    Trade and integration
# 5    2    Public sector governance
# 6    11   Environment and natural resources management
# 8    7    Social dev/gender/inclusion
# 11   4    Financial and private sector development
# 18   10   Rural development
# 53   9    Urban development
# 252  3    Rule of law

# %%
# Rename the columns of the map for later merge
mjtheme_code_map_nonnull.columns=["code_theme","name_theme"]

# %%
# Merge the above map dataframe and the mjtheme_country_df dataframe to get a theme of project column without any missing values
merge_df_nonnull=pd.merge(mjtheme_code_map_nonnull,mjtheme_country_df,left_on='code_theme',right_on='code')

# %%
# there are many duplicate columns after this merge so we drop them.Now we have a dataframe final_df
# with project id, country name, theme of project and corresponding code of the theme
# Note that assumption is that each unique project id identifies a project which may have one or more themes
# If the same theme is repeated under a unique project id, it is treated as one theme
final_df=merge_df_nonnull.drop(columns=["code","name"]).drop_duplicates()

# %%
# display first 10 elements of final_df
final_df.head(10)
# Out:
#    code_theme         name_theme                               countryname  \
# 0   8          Human development  Federal Democratic Republic of Ethiopia
# 1   8          Human development  People's Republic of China
# 2   8          Human development  Republic of Madagascar
# 3   8          Human development  Kingdom of Cambodia
# 6   8          Human development  Republic of Tajikistan
# 8   8          Human development  Lao People's Democratic Republic
# 9   8          Human development  People's Republic of Angola
# 10  8          Human development  People's Republic of Bangladesh
# 11  8          Human development  Republic of Congo
# 12  8          Human development  Democratic Republic of Sao Tome and Prin
#
#          id
# 0   P129828
# 1   P127033
# 2   P132616
# 3   P146271
# 6   P146109
# 8   P143025
# 9   P122700
# 10  P145118
# 11  P128628
# 12  P098847

# %%
# Question 1 Find the 10 countries with most projects. 
# In final_df we can have same id (which represents 1 project) associated with many themes. 
# So we delete the name_theme and code_theme columns , remove duplicate entries and do a value counts on country_name
final_df_countryonly=final_df.drop(columns=["code_theme","name_theme"]).drop_duplicates()

# %%
final_df_countryonly.head(10)
# Out:
#                                  countryname       id
# 0   Federal Democratic Republic of Ethiopia   P129828
# 1   People's Republic of China                P127033
# 2   Republic of Madagascar                    P132616
# 3   Kingdom of Cambodia                       P146271
# 6   Republic of Tajikistan                    P146109
# 8   Lao People's Democratic Republic          P143025
# 9   People's Republic of Angola               P122700
# 10  People's Republic of Bangladesh           P145118
# 11  Republic of Congo                         P128628
# 12  Democratic Republic of Sao Tome and Prin  P098847

# %%
final_df_countryonly_reset=final_df_countryonly.reset_index(drop=True)

# %%
# Answer: Top 10 countries according to number of projects
final_df_countryonly_reset["countryname"].value_counts().head(10)
# Out:
# Republic of Indonesia              19
# People's Republic of China         19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# Kingdom of Morocco                 12
# Nepal                              12
# People's Republic of Bangladesh    12
# Republic of Mozambique             11
# Africa                             11
# Name: countryname, dtype: int64

# %%
# Question 2:Find the top 10 major project themes (using column 'mjtheme_namecode')
# For this we will use the final_df dataframe. 
final_df["name_theme"].value_counts().head(10)
# Out:
# Environment and natural resources management    157
# Rural development                               148
# Public sector governance                        140
# Human development                               128
# Financial and private sector development        119
# Social protection and risk management           116
# Social dev/gender/inclusion                     114
# Trade and integration                           61
# Urban development                               40
# Economic management                             33
# Name: name_theme, dtype: int64

# %%
# Question 3: Fill missing values in project themes 
# We already have final_df dataframe which contains the missing values. We can do some more processing to report it differently
final_df.head(10)
# Out:
#    code_theme         name_theme                               countryname  \
# 0   8          Human development  Federal Democratic Republic of Ethiopia
# 1   8          Human development  People's Republic of China
# 2   8          Human development  Republic of Madagascar
# 3   8          Human development  Kingdom of Cambodia
# 6   8          Human development  Republic of Tajikistan
# 8   8          Human development  Lao People's Democratic Republic
# 9   8          Human development  People's Republic of Angola
# 10  8          Human development  People's Republic of Bangladesh
# 11  8          Human development  Republic of Congo
# 12  8          Human development  Democratic Republic of Sao Tome and Prin
#
#          id
# 0   P129828
# 1   P127033
# 2   P132616
# 3   P146271
# 6   P146109
# 8   P143025
# 9   P122700
# 10  P145118
# 11  P128628
# 12  P098847

# %%
final_df["code_name"]=final_df.apply(lambda row : str(row.code_theme)+":"+str(row.name_theme), axis=1)

# %%
final_df_combined=final_df[["countryname","id","code_name"]]

# %%
# Below output provides country name, project id and all the unique themes ofthe project 
final_df_combined.groupby(['countryname','id'])['code_name'].apply(lambda x: ', '.join(x)).reset_index()
# Out:
#                                   countryname       id  \
# 0    Africa                                    P075941
# 1    Africa                                    P094183
# 2    Africa                                    P118213
# 3    Africa                                    P120370
# 4    Africa                                    P123093
# 5    Africa                                    P125018
# 6    Africa                                    P130174
# 7    Africa                                    P130694
# 8    Africa                                    P130888
# 9    Africa                                    P144902
# 10   Africa                                    P145160
# 11   Antigua and Barbuda                       P126791
# 12   Arab Republic of Egypt                    P117407
# 13   Arab Republic of Egypt                    P127482
# 14   Argentine Republic                        P125804
# 15   Argentine Republic                        P129397
# 16   Bosnia and Herzegovina                    P128950
# 17   Burkina Faso                              P120960
# 18   Burkina Faso                              P128768
# 19   Burkina Faso                              P129688
# 20   Burkina Faso                              P130568
# 21   Burkina Faso                              P130735
# 22   Burkina Faso                              P131061
# 23   Burkina Faso                              P132210
# 24   Burkina Faso                              P143192
# 25   Burkina Faso                              P143833
# 26   Central African Republic                  P133434
# 27   Democratic Republic of Sao Tome and Prin  P098847
# 28   Democratic Republic of Sao Tome and Prin  P130925
# 29   Democratic Republic of Timor-Leste        P130975
# ..                                  ...            ...
# 470  The Independent State of Papua New Guine  P122974
# 471  The Independent State of Papua New Guine  P128763
# 472  The Independent State of Papua New Guine  P129206
# 473  The Independent State of Papua New Guine  P131462
# 474  Tuvalu                                    P145310
# 475  Ukraine                                   P127156
# 476  Ukraine                                   P129704
# 477  Ukraine                                   P131234
# 478  Ukraine                                   P145138
# 479  Union of the Comoros                      P122941
# 480  Union of the Comoros                      P131659
# 481  Union of the Comoros                      P133755
# 482  United Mexican States                     P121116
# 483  United Mexican States                     P130623
# 484  United Republic of Tanzania               P110836
# 485  United Republic of Tanzania               P118152
# 486  United Republic of Tanzania               P124114
# 487  United Republic of Tanzania               P126361
# 488  United Republic of Tanzania               P126875
# 489  United Republic of Tanzania               P132780
# 490  United Republic of Tanzania               P132838
# 491  United Republic of Tanzania               P143645
# 492  West Bank and Gaza                        P101289
# 493  West Bank and Gaza                        P123322
# 494  West Bank and Gaza                        P127163
# 495  West Bank and Gaza                        P129742
# 496  West Bank and Gaza                        P144754
# 497  West Bank and Gaza                        P144967
# 498  World                                     P113794
# 499  World                                     P133572
#
#                                                                                                                                          code_name
# 0    5:Trade and integration, 7:Social dev/gender/inclusion, 4:Financial and private sector development, 10:Rural development
# 1    5:Trade and integration, 10:Rural development
# 2    2:Public sector governance, 4:Financial and private sector development, 10:Rural development
# 3    8:Human development, 5:Trade and integration, 9:Urban development
# 4    5:Trade and integration, 4:Financial and private sector development
# 5    8:Human development, 10:Rural development
# 6    5:Trade and integration, 11:Environment and natural resources management, 10:Rural development, 9:Urban development
# 7    11:Environment and natural resources management, 7:Social dev/gender/inclusion
# 8    11:Environment and natural resources management
# 9    11:Environment and natural resources management
# 10   5:Trade and integration, 2:Public sector governance, 10:Rural development
# 11   6:Social protection and risk management, 2:Public sector governance
# 12   4:Financial and private sector development, 10:Rural development
# 13   8:Human development, 7:Social dev/gender/inclusion
# 14   6:Social protection and risk management, 11:Environment and natural resources management
# 15   11:Environment and natural resources management, 4:Financial and private sector development
# 16   11:Environment and natural resources management, 7:Social dev/gender/inclusion, 3:Rule of law
# 17   5:Trade and integration, 4:Financial and private sector development
# 18   4:Financial and private sector development, 10:Rural development, 9:Urban development
# 19   2:Public sector governance, 11:Environment and natural resources management, 7:Social dev/gender/inclusion, 10:Rural development
# 20   11:Environment and natural resources management, 7:Social dev/gender/inclusion, 10:Rural development
# 21   8:Human development, 6:Social protection and risk management
# 22   8:Human development, 11:Environment and natural resources management
# 23   8:Human development, 2:Public sector governance, 4:Financial and private sector development, 10:Rural development
# 24   8:Human development, 10:Rural development
# 25   10:Rural development
# 26   2:Public sector governance, 7:Social dev/gender/inclusion
# 27   8:Human development, 2:Public sector governance
# 28   1:Economic management, 2:Public sector governance, 4:Financial and private sector development, 10:Rural development
# 29   5:Trade and integration, 11:Environment and natural resources management, 10:Rural development
# ..                                                                                              ...
# 470  11:Environment and natural resources management, 4:Financial and private sector development, 10:Rural development
# 471  6:Social protection and risk management, 9:Urban development
# 472  8:Human development, 11:Environment and natural resources management
# 473  11:Environment and natural resources management, 7:Social dev/gender/inclusion
# 474  6:Social protection and risk management, 5:Trade and integration, 2:Public sector governance, 11:Environment and natural resources management
# 475  5:Trade and integration, 4:Financial and private sector development
# 476  6:Social protection and risk management, 11:Environment and natural resources management
# 477  8:Human development, 1:Economic management
# 478  11:Environment and natural resources management
# 479  6:Social protection and risk management, 2:Public sector governance
# 480  4:Financial and private sector development
# 481  6:Social protection and risk management, 7:Social dev/gender/inclusion, 10:Rural development
# 482  11:Environment and natural resources management, 10:Rural development
# 483  11:Environment and natural resources management, 10:Rural development
# 484  1:Economic management, 5:Trade and integration, 2:Public sector governance, 4:Financial and private sector development
# 485  2:Public sector governance, 9:Urban development
# 486  1:Economic management, 2:Public sector governance
# 487  11:Environment and natural resources management
# 488  11:Environment and natural resources management, 7:Social dev/gender/inclusion, 4:Financial and private sector development
# 489  10:Rural development
# 490  8:Human development, 4:Financial and private sector development, 10:Rural development
# 491  2:Public sector governance, 4:Financial and private sector development
# 492  4:Financial and private sector development, 9:Urban development
# 493  11:Environment and natural resources management, 10:Rural development
# 494  11:Environment and natural resources management, 7:Social dev/gender/inclusion, 9:Urban development
# 495  8:Human development, 6:Social protection and risk management, 2:Public sector governance
# 496  6:Social protection and risk management, 7:Social dev/gender/inclusion
# 497  6:Social protection and risk management, 7:Social dev/gender/inclusion
# 498  11:Environment and natural resources management, 7:Social dev/gender/inclusion
# 499  8:Human development, 10:Rural development
#
# [500 rows x 3 columns]

# %% [markdown]
# So in summary
# 1. Question 1: Top 10 countries
# Republic of Indonesia              19
# People's Republic of China         19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# Kingdom of Morocco                 12
# Nepal                              12
# People's Republic of Bangladesh    12
# Republic of Mozambique             11
# Africa                             11
# Name: countryname, dtype: int64
#
# 2. Question 2: Top 10 project themes
# Environment and natural resources management    157
# Rural development                               148
# Public sector governance                        140
# Human development                               128
# Financial and private sector development        119
# Social protection and risk management           116
# Social dev/gender/inclusion                     114
# Trade and integration                           61
# Urban development                               40
# Economic management                             33
#
# 3. Question 3: No missing values under name
# Examine final_df_combined.groupby(['countryname','id'])['code_name'].apply(lambda x: ', '.join(x)).reset_index() in the previous step
